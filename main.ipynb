# %% [markdown]
# ## # ELEVATE LABS AI/ML INTERNSHIP
# ## Task-4 by Harsimran singh
# ### Dated - 27 june 2025
# ## Breast Cancer Wisconsin (Diagnostic) Data Set

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.isnull().sum()
df.shape
# Out:
# (569, 33)

# %%
## dropping last column
#df.drop('Unnamed: 32,',axis=1,inplace=True)
df.drop('id',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 3
#       1 ## dropping last column
#       2 #df.drop('Unnamed: 32,',axis=1,inplace=True)
# ----> 3 df.drop('id',axis=1,inplace=True)
#
# File c:\harsimran\Elevate labs\task_4\venv\Lib\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
# ...

# %%
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    int64
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %%
df['diagnosis'] =  np.where(df['diagnosis'].str.contains('M'),1,0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 df['diagnosis'] =  np.where(df['diagnosis'].str.contains('M'),1,0)
#
# File c:\harsimran\Elevate labs\task_4\venv\Lib\site-packages\pandas\core\generic.py:6318, in NDFrame.__getattr__(self, name)
#    6311 if (
#    6312     name not in self._internal_names_set
#    6313     and name not in self._metadata
#    6314     and name not in self._accessors
#    6315     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316 ):
#    6317     return self[name]
# -> 6318 return object.__getattribute__(self, name)
#
# File c:\harsimran\Elevate labs\task_4\venv\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# ...

# %%
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
df['diagnosis'].value_counts()
# Out:
# diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
def get_highly_correlated_features(df, threshold=0.9):
    """
    Finds features with correlation greater than the given threshold.

    Args:
        df (pd.DataFrame): Dataset with only numeric features
        threshold (float): Correlation threshold (default 0.9)

    Returns:
        List[str]: List of features recommended for removal
    """
    corr_matrix = df.corr().abs()  # Absolute correlations
    upper_triangle = corr_matrix.where(
        np.triu(np.ones(corr_matrix.shape), k=1).astype(bool)
    )

    to_drop = [
        column for column in upper_triangle.columns 
        if any(upper_triangle[column] > threshold)
    ]

    return to_drop

# %%
high_corr_features = get_highly_correlated_features(df.corr(), threshold=0.9)
print("Highly Correlated Features to Drop:", high_corr_features)
print("length",len(high_corr_features))
# Out:
# Highly Correlated Features to Drop: ['radius_mean', 'perimeter_mean', 'area_mean', 'concave points_mean', 'perimeter_se', 'area_se', 'concavity_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst']
# length 14

# %%
## droping them

df_new = df.drop(high_corr_features,axis=1)

# %%
df_new.head()
# Out:
#    diagnosis  texture_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0          1         10.38          0.11840           0.27760          0.3001
# 1          1         17.77          0.08474           0.07864          0.0869
# 2          1         21.25          0.10960           0.15990          0.1974
# 3          1         20.38          0.14250           0.28390          0.2414
# 4          1         14.34          0.10030           0.13280          0.1980
#
#    symmetry_mean  fractal_dimension_mean  radius_se  texture_se  \
# 0         0.2419                 0.07871     1.0950      0.9053
# 1         0.1812                 0.05667     0.5435      0.7339
# 2         0.2069                 0.05999     0.7456      0.7869
# 3         0.2597                 0.09744     0.4956      1.1560
# 4         0.1809                 0.05883     0.7572      0.7813
#
#    smoothness_se  compactness_se  concave points_se  symmetry_se  \
# ...

# %%
sns.heatmap(df_new.corr())
# Out:
# <Axes: >

# %%
sns.boxplot(df_new)
# Out:
# <Axes: >

# %%
y=df_new['diagnosis']
X = df_new.drop('diagnosis',axis=1)

# %%
X
# Out:
#      texture_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0           10.38          0.11840           0.27760         0.30010
# 1           17.77          0.08474           0.07864         0.08690
# 2           21.25          0.10960           0.15990         0.19740
# 3           20.38          0.14250           0.28390         0.24140
# 4           14.34          0.10030           0.13280         0.19800
# ..            ...              ...               ...             ...
# 564         22.39          0.11100           0.11590         0.24390
# 565         28.25          0.09780           0.10340         0.14400
# 566         28.08          0.08455           0.10230         0.09251
# 567         29.33          0.11780           0.27700         0.35140
# 568         24.54          0.05263           0.04362         0.00000
#
#      symmetry_mean  fractal_dimension_mean  radius_se  texture_se  \
# 0           0.2419                 0.07871     1.0950      0.9053
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
# Out:
# c:\harsimran\Elevate labs\task_4\venv\Lib\site-packages\sklearn\utils\extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# c:\harsimran\Elevate labs\task_4\venv\Lib\site-packages\sklearn\utils\extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# c:\harsimran\Elevate labs\task_4\venv\Lib\site-packages\sklearn\utils\extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count

# %%
sns.boxplot(X_scaled)
# Out:
# <Axes: >

# %%
sns.boxplot(X)
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LogisticRegression
